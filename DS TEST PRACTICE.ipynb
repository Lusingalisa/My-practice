# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("Cassava_Yield_Data.xlsx")

# %%
data
# Out:
#      Sesn  locn  block  rep tillage    ferT  Plants_harvested  No_bigtubers  \
# 0       2     1      1    1     conv  F2150                28             0
# 1       2     1      1    1     conv  F1100                28             0
# 2       2     1      1    1     conv  F3200                28             2
# 3       2     1      1    1     conv  F5300                28             6
# 4       2     1      1    1     conv  F4250                28             3
# ..    ...   ...    ...  ...      ...    ...               ...           ...
# 110     2     2      3    3     conv  F1100                19             0
# 111     2     2      3    3     conv  F5300                16             0
# 112     2     2      3    3     conv  F2150                13             0
# 113     2     2      3    3     conv  F4250                20             0
# 114     2     2      3    3     conv  F3200                19             0
#
# ...

# %%
data.shape
# Out:
# (115, 20)

# %%
data.dtypes
# Out:
# Sesn                       int64
# locn                       int64
# block                      int64
# rep                        int64
# tillage                   object
# ferT                      object
# Plants_harvested           int64
# No_bigtubers               int64
# Weigh_bigtubers          float64
# No_mediumtubers            int64
# Weight_mediumtubers      float64
# No_smalltubers             int64
# Weight_smalltubers       float64
# Totaltuberno               int64
# AV_tubers_Plant          float64
# Total_tubweight          float64
# plotsize                 float64
# HEC                        int64
# TotalWeightperhectare    float64
# TotalTuberperHectare     float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Sesn                     0
# locn                     0
# block                    0
# rep                      0
# tillage                  0
# ferT                     0
# Plants_harvested         0
# No_bigtubers             0
# Weigh_bigtubers          0
# No_mediumtubers          0
# Weight_mediumtubers      0
# No_smalltubers           0
# Weight_smalltubers       0
# Totaltuberno             0
# AV_tubers_Plant          0
# Total_tubweight          0
# plotsize                 0
# HEC                      0
# TotalWeightperhectare    0
# TotalTuberperHectare     0
# dtype: int64

# %%
diamonds=pd.read_csv("DiamondPricesData.csv")

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.dtypes
# Out:
# price        int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
diamonds.isnull().sum()
# Out:
# price       0
# carat       0
# cut         0
# color       6
# clarity     0
# depth      14
# table       0
# x           0
# y           0
# z           0
# dtype: int64

# %%
diamonds.describe(include='all')
# Out:
#                price         carat    cut  color clarity         depth  \
# count   53940.000000  53940.000000  53940  53934   53940  53926.000000
# unique           NaN           NaN      5      7       8           NaN
# top              NaN           NaN  Ideal      G     SI1           NaN
# freq             NaN           NaN  21551  11286   13065           NaN
# mean     3932.799722      0.797940    NaN    NaN     NaN     61.749479
# std      3989.439738      0.474011    NaN    NaN     NaN      1.432661
# min       326.000000      0.200000    NaN    NaN     NaN     43.000000
# 25%       950.000000      0.400000    NaN    NaN     NaN     61.000000
# 50%      2401.000000      0.700000    NaN    NaN     NaN     61.800000
# 75%      5324.250000      1.040000    NaN    NaN     NaN     62.500000
# max     18823.000000      5.010000    NaN    NaN     NaN     79.000000
#
#                table             x             y             z
# ...

# %%
diamonds.duplicated().sum()
# Out:
# np.int64(146)

# %%
diamonds.drop_duplicates(inplace=True)

# %%
diamonds.interpolate()
# Out:
# /var/folders/rc/wkv7nt2n7xq5_bg0xvtzth3w0000gn/T/ipykernel_937/4122300104.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   diamonds.interpolate()
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# ...

# %%
cont_data=diamonds.select_dtypes(include=['int64', 'float64'])

# %%
cont_data.head()
# Out:
#    price  carat  depth  table     x     y     z
# 0    326   0.23   61.5   55.0  3.95  3.98  2.43
# 1    326   0.21   59.8   61.0  3.89  3.84  2.31
# 2    327   0.23   56.9   65.0  4.05  4.07  2.31
# 3    334   0.29   62.4   58.0  4.20  4.23  2.63
# 4    335   0.31   63.3   58.0  4.34  4.35  2.75

# %%
cat_data=diamonds.select_dtypes(include=['object'])

# %%
cat_data.head()
# Out:
#        cut color clarity
# 0    Ideal     E     SI2
# 1  Premium     E     SI1
# 2     Good     E     VS1
# 3  Premium     I     VS2
# 4     Good     J     SI2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,3, i+1)
    plt.hist(diamonds[col])
    plt.title(col)
    plt.ylabel("frequency")
plt.tight_layout()
plt.show()

# %%
diamonds.isnull().sum()
# Out:
# price       0
# carat       0
# cut         0
# color       6
# clarity     0
# depth      14
# table       0
# x           0
# y           0
# z           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,3, i+1)
    plt.boxplot(cont_data[col])
    plt.title(col)
    plt.ylabel(f"frequency")
plt.tight_layout()
plt.show()

# %%
contdata=['price']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i, col in enumerate(contdata):
    plt.boxplot(diamonds[col])
    plt.title(col)
    plt.ylabel("frequency")
plt.tight_layout()
plt.show()

# %%
Contdata=['carat']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i, col in enumerate(Contdata):
    plt.boxplot(diamonds[col])
    plt.title(col)
    plt.ylabel("Freq")
plt.tight_layout()
plt.show()

# %%
import numpy as np

def remove_outliers(column):
    for column in column:
        lower_quantile = cont_data[column].quantile(.25)
        upper_quantile = cont_data[column].quantile(.75)

        IQR = upper_quantile-lower_quantile

        upper_boundary = upper_quantile + 1.5 *IQR
        lower_boundary = lower_quantile - 1.5 *IQR

        cont_data[column] = np.where(cont_data[column]>upper_boundary,upper_boundary,cont_data[column])
        cont_data[column] = np.where(cont_data[column]<lower_boundary,lower_boundary,cont_data[column])

# %%
remove_outliers(cont_data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,3, i+1)
    plt.boxplot(cont_data[col])
    plt.title(col)
    plt.ylabel("frequency")
plt.tight_layout()
plt.show()

# %%
diamonds['carat'].describe
# Out:
# <bound method NDFrame.describe of 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53794, dtype: float64>

# %%
continuous=['price']
for predictor in continuous:
    diamonds.plot.scatter(x=predictor,y='carat', figsize=(10,8), title=predictor+ "VS"+ "carat")

# %%
def FunctionAnova(inpData,Targetvariable,CategoricalPredictorList):
    from scipy.stats import f_oneway
    SelectedPredictors=[]
    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[Targetvariable].apply(list)
        AnovaResults=f_oneway(*CategoryGroupLists)
        if (AnovaResults[1] <0.05):
            print(predictor, 'is correlated with', TargetVariable, '|P-value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '|P-value:', AnovaResults[1])

    return(SelectedPredictors)

# %%
CategoricalColsList=['cut',	'color', 'clarity']

# %%
CategoricalColsList=['cut',	'color', 'clarity']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=1, ncols=len(CategoricalColsList), figsize=(10,8))

for PredictorCol, i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    diamonds.boxplot(column='price', by=PredictorCol, figsize=(10,8), vert=True, ax=PlotCanvas[i])

# %%
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList)
