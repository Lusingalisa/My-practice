# %%
#Have to import library to use its codes
#And import it as a short-form name "pd"
import pandas as pd

# %%
#Import my data set called Cassava_Yield_Data
pd.read_excel("Cassava_Yield_Data.xlsx")
# Out:
#      Sesn  locn  block  rep tillage    ferT  Plants_harvested  No_bigtubers  \
# 0       2     1      1    1     conv  F2150                28             0
# 1       2     1      1    1     conv  F1100                28             0
# 2       2     1      1    1     conv  F3200                28             2
# 3       2     1      1    1     conv  F5300                28             6
# 4       2     1      1    1     conv  F4250                28             3
# ..    ...   ...    ...  ...      ...    ...               ...           ...
# 110     2     2      3    3     conv  F1100                19             0
# 111     2     2      3    3     conv  F5300                16             0
# 112     2     2      3    3     conv  F2150                13             0
# 113     2     2      3    3     conv  F4250                20             0
# 114     2     2      3    3     conv  F3200                19             0
#
# ...

# %%
#turn dataset into pandas dataframe
data=pd.read_excel("Cassava_Yield_Data.xlsx")

# %%
#view dataframe
data
# Out:
#      Sesn  locn  block  rep tillage    ferT  Plants_harvested  No_bigtubers  \
# 0       2     1      1    1     conv  F2150                28             0
# 1       2     1      1    1     conv  F1100                28             0
# 2       2     1      1    1     conv  F3200                28             2
# 3       2     1      1    1     conv  F5300                28             6
# 4       2     1      1    1     conv  F4250                28             3
# ..    ...   ...    ...  ...      ...    ...               ...           ...
# 110     2     2      3    3     conv  F1100                19             0
# 111     2     2      3    3     conv  F5300                16             0
# 112     2     2      3    3     conv  F2150                13             0
# 113     2     2      3    3     conv  F4250                20             0
# 114     2     2      3    3     conv  F3200                19             0
#
# ...

# %%
#Main information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sesn                   115 non-null    int64
#  1   locn                   115 non-null    int64
#  2   block                  115 non-null    int64
#  3   rep                    115 non-null    int64
#  4   tillage                115 non-null    object
#  5   ferT                   115 non-null    object
#  6   Plants_harvested       115 non-null    int64
#  7   No_bigtubers           115 non-null    int64
#  8   Weigh_bigtubers        115 non-null    float64
#  9   No_mediumtubers        115 non-null    int64
#  10  Weight_mediumtubers    115 non-null    float64
#  11  No_smalltubers         115 non-null    int64
#  12  Weight_smalltubers     115 non-null    float64
#  13  Totaltuberno           115 non-null    int64
# ...

# %%
#checking the descriptive statistics (Central tendency, variability)
data.describe()
# Out:
#              Sesn        locn       block         rep  Plants_harvested  \
# count  115.000000  115.000000  115.000000  115.000000        115.000000
# mean     1.521739    1.521739    2.043478    2.043478         18.565217
# std      0.501713    0.501713    0.809931    0.809931          6.442908
# min      1.000000    1.000000    1.000000    1.000000          5.000000
# 25%      1.000000    1.000000    1.000000    1.000000         14.000000
# 50%      2.000000    2.000000    2.000000    2.000000         18.000000
# 75%      2.000000    2.000000    3.000000    3.000000         28.000000
# max      2.000000    2.000000    3.000000    3.000000         28.000000
#
#        No_bigtubers  Weigh_bigtubers  No_mediumtubers  Weight_mediumtubers  \
# count    115.000000       115.000000       115.000000           115.000000
# mean       4.000000         0.614783        49.521739             2.771304
# std        7.367544         1.174678        29.920757             1.774911
# ...

# %%
data.isnull().sum()
# Out:
# Sesn                     0
# locn                     0
# block                    0
# rep                      0
# tillage                  0
# ferT                     0
# Plants_harvested         0
# No_bigtubers             0
# Weigh_bigtubers          0
# No_mediumtubers          0
# Weight_mediumtubers      0
# No_smalltubers           0
# Weight_smalltubers       0
# Totaltuberno             0
# AV_tubers_Plant          0
# Total_tubweight          0
# plotsize                 0
# HEC                      0
# TotalWeightperhectare    0
# TotalTuberperHectare     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Sesn', 'locn', 'block', 'rep', 'tillage ', 'ferT', 'Plants_harvested',
#        'No_bigtubers', 'Weigh_bigtubers', 'No_mediumtubers',
#        'Weight_mediumtubers', 'No_smalltubers', 'Weight_smalltubers',
#        'Totaltuberno', 'AV_tubers_Plant', 'Total_tubweight', 'plotsize', 'HEC',
#        'TotalWeightperhectare', 'TotalTuberperHectare'],
#       dtype='object')

# %%
data.hist(bins=60, figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Sesn'}>,
#         <Axes: title={'center': 'locn'}>,
#         <Axes: title={'center': 'block'}>,
#         <Axes: title={'center': 'rep'}>],
#        [<Axes: title={'center': 'Plants_harvested'}>,
#         <Axes: title={'center': 'No_bigtubers'}>,
#         <Axes: title={'center': 'Weigh_bigtubers'}>,
#         <Axes: title={'center': 'No_mediumtubers'}>],
#        [<Axes: title={'center': 'Weight_mediumtubers'}>,
#         <Axes: title={'center': 'No_smalltubers'}>,
#         <Axes: title={'center': 'Weight_smalltubers'}>,
#         <Axes: title={'center': 'Totaltuberno'}>],
#        [<Axes: title={'center': 'AV_tubers_Plant'}>,
#         <Axes: title={'center': 'Total_tubweight'}>,
#         <Axes: title={'center': 'plotsize'}>,
#         <Axes: title={'center': 'HEC'}>],
#        [<Axes: title={'center': 'TotalWeightperhectare'}>,
#         <Axes: title={'center': 'TotalTuberperHectare'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
data.boxplot(column='Plants_harvested')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.boxplot(['Sesn'])
# Out:
# <Axes: >

# %%
#importing the required function
from scipy.stats import chi2_contingency

# %% [markdown]
# to find missing information

# %%
data.isna().sum()
# Out:
# Sesn                     0
# locn                     0
# block                    0
# rep                      0
# tillage                  0
# ferT                     0
# Plants_harvested         0
# No_bigtubers             0
# Weigh_bigtubers          0
# No_mediumtubers          0
# Weight_mediumtubers      0
# No_smalltubers           0
# Weight_smalltubers       0
# Totaltuberno             0
# AV_tubers_Plant          0
# Total_tubweight          0
# plotsize                 0
# HEC                      0
# TotalWeightperhectare    0
# TotalTuberperHectare     0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Sesn                     0
# locn                     0
# block                    0
# rep                      0
# tillage                  0
# ferT                     0
# Plants_harvested         0
# No_bigtubers             0
# Weigh_bigtubers          0
# No_mediumtubers          0
# Weight_mediumtubers      0
# No_smalltubers           0
# Weight_smalltubers       0
# Totaltuberno             0
# AV_tubers_Plant          0
# Total_tubweight          0
# plotsize                 0
# HEC                      0
# TotalWeightperhectare    0
# TotalTuberperHectare     0
# dtype: int64

# %%
ContinuousCols=['Plants_harvested']
for predictor in ContinuousCols:
  data.plot.scatter(x=predictor, y='No_mediumtubers', figsize =(10,5), title= predictor+"VS"+ 'No_mediumtubers')
